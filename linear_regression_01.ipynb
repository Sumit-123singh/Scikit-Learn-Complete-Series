# %%
from sklearn.linear_model import LinearRegression

# %%
x=[[1],[2],[3],[4],[5]]
y=[30,35,40,45,50]



model=LinearRegression()
model.fit(x,y)
print("predicted salary for 6 years experience :" ,model.predict([[6]]))
# Out:
# predicted salary for 6 years experience : [55.]
